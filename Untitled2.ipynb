# %%
from sqlalchemy import create_engine
import geopandas as gp
import multiprocessing
import zipfile as zp
import pandas as pd
import numpy as np
import shutil
import os
from IPython.display import clear_output, display
import time
import concurrent.futures as cf
engine.dispose()

df = pd.read_csv(r'E:\combined.csv')
shp_df = df[df.Ext == 'shp']
shp_df.head()


# Function to read shape files into a temp directory
def shp_zip_read(full_path):
    os.makedirs(r"E:\New folder", exist_ok=True)
    zip_file_path = full_path.split('.zip\\')[0]
    shp_file_path = full_path.split('.zip\\')[1]
    archive = zp.ZipFile(zip_file_path)
    if '/' not in shp_file_path:
        for file in archive.namelist():
            if '/' not in file:
                archive.extract(file, r"E:\New folder")
    else:
        shpfile_folder_path = '/'.join(file_zip_path.split('/')[:-1])+'/'
        for file in archive.namelist():
            if file.startswith(shpfile_folder_path):
                archive.extract(file, r"E:\New folder")
    gdf = gp.read_file(r"E:\New folder\{}".format(file_zip_path))
    shutil.rmtree(r'E:\New folder', ignore_errors=True)
    return gdf


# Function to dump shape files into postgres db 
def shape_file_dump(file_name, file_path, engine):
    
    #connection = engine.connect()
    
    # Reading the shape file
    if '.zip' in file_path:
        gdf = shp_zip_read(file_path)
    else:
        gdf = gp.read_file(file_path)

    #Import shapefile to databse
    #print(file_name)
    gdf.to_postgis(name=file_name, con=engine, schema="postgis")
    
    #connection.close()
    

# Deriving a unique file name to create table in the database 
import hashlib
class FilePathShortener:
    def __init__(self):
        self.paths = {}
    
    def shorten_file_path(self, file_path):
        if file_path in self.paths:
            return self.paths[file_path]
        
        file_hash = hashlib.md5(file_path.encode()).hexdigest()
        shortened_path = file_hash[:8]
        
        self.paths[file_path] = shortened_path
        return shortened_path
    
    def decode_shortened_path(self, shortened_path):
        for path, short_path in self.paths.items():
            if short_path == shortened_path:
                return path
        
        return None

shortener = FilePathShortener()

 

"""file_path = '\\\\192.168.1.151\\ncfc_data3\\Neetu Mam (IP 26 Data Backup 17 April 23)\\Backup_Del\\Transfer-data\\Sent-Analysis\\shp\\0.India_state_shp\\india state_lcc.shp'
shortened_path = shortener.shorten_file_path(file_path)
print(shortened_path)"""

shortened_path = shp_df.File_path.apply(shortener.shorten_file_path) 
new_file_name = shp_df.File_Name+'_'+shortened_path
shp_df['unique_file_name']=new_file_name
        
    
if __name__ == '__main__':
    # Number of processes to run in parallel
    num_processes = multiprocessing.cpu_count()
        
    #DB details
    host = 'localhost'
    port = '5432'
    database = 'postgis_33'
    user = 'postgres'
    password = 'wadhwanikdss'

    conn = f"postgresql://{user}:{password}@{host}:{port}/{database}"
    engine = create_engine(conn)
            
#     # Create a list to store the process instances
#     processes = []

#     for _ in range(num_processes):
#         p = multiprocessing.Process(target=shape_file_dump, args=(list(shp_df.File_Name), list(shp_df.File_path), engine))
#         p.start()
#         processes.append(p)

#     # Wait for all processes to finish
#     for p in processes:
#         p.join()
    
    j = 1
    
    
    df = pd.DataFrame(columns=['file_path', 'error'])   
    for i in range(shp_df.shape[0]):
        print(f'Executing {i}st file')
        try:
            shape_file_dump(shp_df.unique_file_name.iloc[i], shp_df.File_path.iloc[i], engine)
            #print(shp_df.unique_file_name.iloc[i])
        except Exception as e:
            print(e, shp_df.File_path.iloc[i])
            df.loc[len(df.index)] = [shp_df.File_path.iloc[i], e]
            #lst.append(shp_df.File_path.iloc[i])

    print("Data dumped successfully into the PostGIS database.")
    
    engine.dispose()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9348\3465832837.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df['unique_file_name']=new_file_name
# Executing 0st file
# Table 'Cotton_States_41d30cad' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\2018-19\Cotton_States.shp
# Executing 1st file
# Table 'Banswara_9e90aae4' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\2018-19\Double stress districtplan\Banswara.shp
# Executing 2st file
# Table 'Rajasthan_b0ad2740' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\2018-19\Double stress districtplan\Rajasthan.shp
# Executing 3st file
# Table 'Sirmaur_cce49301' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\HP\Sirmaur.shp
# Executing 4st file
# Table 'sirmaur_lcc_7f8a3da6' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\HP\sirmaur_lcc.shp
# Executing 5st file
# Table 'New_Shapefile_ba887c64' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\HP\New Folder\New_Shapefile.shp
# Executing 6st file
# Table 'Sirmaur_51c1860a' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\HP\sirmaur\Sirmaur.shp
# Executing 7st file
# Table 'sirmaur_lcc_7ebcfce4' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\HP\sirmaur\sirmaur_lcc.shp
# Executing 8st file
# Table 'Aoi_region_5e5032b8' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\lulc_manoj\SHP\Aoi_region.shp
# Executing 9st file
# Table 'Building_region_d62d002e' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\lulc_manoj\SHP\Building_region.shp
# Executing 10st file
# Table 'Center Line_polyline_e20555c2' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\lulc_manoj\SHP\Center Line_polyline.shp
# Executing 11st file
# Table 'Footpath_region_eb63d6de' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\lulc_manoj\SHP\Footpath_region.shp
# Executing 12st file
# Table 'Green_region_62135b84' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\lulc_manoj\SHP\Green_region.shp
# Executing 13st file
# Table 'Locality_region_091220de' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\lulc_manoj\SHP\Locality_region.shp
# Executing 14st file
# Table 'Non Built up_region_28543e9e' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\lulc_manoj\SHP\Non Built up_region.shp
# Executing 15st file
# Table 'Obstacle Route_polyline_6572b6e6' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\lulc_manoj\SHP\Obstacle Route_polyline.shp
# Executing 16st file
# Table 'Plot Boundary_region_6a6a2301' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\lulc_manoj\SHP\Plot Boundary_region.shp
# Executing 17st file
# Table 'Power Boundary_region_9f391878' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\lulc_manoj\SHP\Power Boundary_region.shp
# Executing 18st file
# Table 'Power Point_point_27b4285c' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\lulc_manoj\SHP\Power Point_point.shp
# Executing 19st file
# Table 'Railway Line_polyline_f7ee1e2f' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\lulc_manoj\SHP\Railway Line_polyline.shp
# Executing 20st file
# Table 'Road Width_polyline_66e83dbf' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\lulc_manoj\SHP\Road Width_polyline.shp
# Executing 21st file
# Table 'Transit Points_point_e806bc0b' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\lulc_manoj\SHP\Transit Points_point.shp
# Executing 22st file
# Table 'Transit_Area_region_132ba875' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\lulc_manoj\SHP\Transit_Area_region.shp
# Executing 23st file
# Table 'Water Boundary_region_a0d4bbd4' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\lulc_manoj\SHP\Water Boundary_region.shp
# Executing 24st file
# Table 'Water Route_polyline_2f62e038' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\lulc_manoj\SHP\Water Route_polyline.shp
# Executing 25st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\Akhilesh\\akhileshPP\\PP_work\\RD\\xacto_ArcGIS101_062014' \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\xacto_ArcGIS101_062014.zip\input_files/freeburg_xs_line.shp
# Executing 26st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\Akhilesh\\akhileshPP\\PP_work\\RD\\xacto_ArcGIS101_062014' \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\xacto_ArcGIS101_062014.zip\input_files/freeburg_xs_poly.shp
# Executing 27st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\Akhilesh\\akhileshPP\\PP_work\\RD\\xacto_ArcGIS101_062014' \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\xacto_ArcGIS101_062014.zip\input_files/freeburg_xs_wells.shp
# Executing 28st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\Akhilesh\\akhileshPP\\PP_work\\RD\\xacto_ArcGIS101_062014' \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\xacto_ArcGIS101_062014.zip\input_files/xsec_A_poly.shp
# Executing 29st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\Akhilesh\\akhileshPP\\PP_work\\RD\\xacto_ArcGIS101_062014' \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\xacto_ArcGIS101_062014.zip\output_files/3d_polys.shp
# Executing 30st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\Akhilesh\\akhileshPP\\PP_work\\RD\\xacto_ArcGIS101_062014' \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\xacto_ArcGIS101_062014.zip\output_files/3d_test.shp
# Executing 31st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\Akhilesh\\akhileshPP\\PP_work\\RD\\xacto_ArcGIS101_062014' \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\xacto_ArcGIS101_062014.zip\output_files/xsec_A_BT.shp
# Executing 32st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\Akhilesh\\akhileshPP\\PP_work\\RD\\xacto_ArcGIS101_062014' \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\xacto_ArcGIS101_062014.zip\output_files/xsec_A_depths.shp
# Executing 33st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\Akhilesh\\akhileshPP\\PP_work\\RD\\xacto_ArcGIS101_062014' \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\xacto_ArcGIS101_062014.zip\output_files/xsec_A_geophys.shp
# Executing 34st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\Akhilesh\\akhileshPP\\PP_work\\RD\\xacto_ArcGIS101_062014' \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\xacto_ArcGIS101_062014.zip\output_files/xsec_A_geopts.shp
# Executing 35st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\Akhilesh\\akhileshPP\\PP_work\\RD\\xacto_ArcGIS101_062014' \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\xacto_ArcGIS101_062014.zip\output_files/xsec_A_GridLine.shp
# Executing 36st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\Akhilesh\\akhileshPP\\PP_work\\RD\\xacto_ArcGIS101_062014' \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\xacto_ArcGIS101_062014.zip\output_files/xsec_A_profile.shp
# Executing 37st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\Akhilesh\\akhileshPP\\PP_work\\RD\\xacto_ArcGIS101_062014' \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\xacto_ArcGIS101_062014.zip\output_files/xsec_A_wellln.shp
# Executing 38st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\Akhilesh\\akhileshPP\\PP_work\\RD\\xacto_ArcGIS101_062014' \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\xacto_ArcGIS101_062014.zip\output_files/xsec_A_wellpt.shp
# Executing 39st file
# Table 'freeburg_xs_line_e3dd0c62' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\input_files\freeburg_xs_line.shp
# Executing 40st file
# Table 'freeburg_xs_poly_ed7791fb' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\input_files\freeburg_xs_poly.shp
# Executing 41st file
# Table 'freeburg_xs_wells_c6f076c8' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\input_files\freeburg_xs_wells.shp
# Executing 42st file
# Table 'xsec_A_poly_cb8f65f8' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\input_files\xsec_A_poly.shp
# Executing 43st file
# Table '3d_polys_fb980c2e' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\output_files\3d_polys.shp
# Executing 44st file
# Table '3d_test_b7c7b8db' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\output_files\3d_test.shp
# Executing 45st file
# Table 'xsec_A_BT_b3f47264' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\output_files\xsec_A_BT.shp
# Executing 46st file
# Table 'xsec_A_depths_a7b6d905' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\output_files\xsec_A_depths.shp
# Executing 47st file
# C:\Users\user\miniconda3\envs\kdss\lib\site-packages\geopandas\io\sql.py:415: UserWarning: Could not parse CRS from the GeoDataFrame. Inserting data without defined CRS.
#   srid = _get_srid_from_crs(gdf)
# Table 'xsec_A_geophys_8b36a541' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\output_files\xsec_A_geophys.shp
# Executing 48st file
# Table 'xsec_A_geopts_4b2c1638' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\output_files\xsec_A_geopts.shp
# Executing 49st file
# C:\Users\user\miniconda3\envs\kdss\lib\site-packages\geopandas\io\sql.py:415: UserWarning: Could not parse CRS from the GeoDataFrame. Inserting data without defined CRS.
#   srid = _get_srid_from_crs(gdf)
# Table 'xsec_A_GridLine_c6b8b9f6' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\output_files\xsec_A_GridLine.shp
# Executing 50st file
# Table 'xsec_A_profile_5c407721' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\output_files\xsec_A_profile.shp
# Executing 51st file
# Table 'xsec_A_wellln_55f7ad9c' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\output_files\xsec_A_wellln.shp
# Executing 52st file
# Table 'xsec_A_wellpt_2615edd5' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\RD\output_files\xsec_A_wellpt.shp
# Executing 53st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\Akhilesh\\Sugercane\\UP_sugercane\\F1\\GT\\NCFCCrop2017062392731' \\192.168.1.151\ncfc_data3\Akhilesh\Sugercane\UP_sugercane\F1\GT\NCFCCrop2017062392731.zip\shape/NCFCCrop2017062392731.shp
# Executing 54st file
# Table 'UP_sugercane_District_7d8d132d' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\Sugercane\UP_sugercane\F2\UP_sugercane_District.shp
# Executing 55st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\Akhilesh\\Sugercane\\UP_sugercane\\F2\\up_gt\\NCFCCrop2017112161157' \\192.168.1.151\ncfc_data3\Akhilesh\Sugercane\UP_sugercane\F2\up_gt\NCFCCrop2017112161157.zip\shape/NCFCCrop2017112161157.shp
# Executing 56st file
# Table 'Sugercane_GT_92ee4c27' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\Sugercane\UP_sugercane\F2\up_gt\Sugercane_GT.shp
# Executing 57st file
# Table 'SugerCane_District_e927109c' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\Sugercane\UP_sugercane\F2\Vector data\SugerCane_District.shp
# Executing 58st file
# Table '36-Dist_up_albrs_62173c01' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\Wheat\F1\36-Dist_up_albrs.shp
# Executing 59st file
# Table '36-dist_up_lcc_6105c574' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\Wheat\F1\36-dist_up_lcc.shp
# Executing 60st file
# Table 'UP_withoutcloudDistrict_e18c4ff1' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\Wheat\F1\2017-18\AWiFS_ndvi_product\Cloud Free\UP_withoutcloudDistrict.shp
# Executing 61st file
# [Errno 13] Permission denied: '\\\\192.168.1.151\\ncfc_data3\\Akhilesh\\Wheat\\F1\\2017-18\\Ground truth\\NCFCCrop20180125123034_up' \\192.168.1.151\ncfc_data3\Akhilesh\Wheat\F1\2017-18\Ground truth\NCFCCrop20180125123034_up.zip\shape/NCFCCrop20180125123034.shp
# Executing 62st file
# Table 'NCFCCrop20180125123034_9d019779' already exists. \\192.168.1.151\ncfc_data3\Akhilesh\Wheat\F1\2017-18\Ground truth\NCFCCrop20180125123034_up\shape\NCFCCrop20180125123034.shp
# Executing 63st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\CHAMAN\\Chaman20160718104510' \\192.168.1.151\ncfc_data3\CHAMAN\Chaman20160718104510.zip\shape/Chaman20160718104510.shp
# Executing 64st file
# Table 'ambal_yam_561d57be' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\aditi\ambal_yam.shp
# Executing 65st file
# Table 'Firozpur_mukhtsar_787bca4a' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\aditi\Firozpur_mukhtsar.shp
# Executing 66st file
# Table 'Yamunanagar_8708f864' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\aditi\Yamunanagar.shp
# Executing 67st file
# Table 'gt_points1_d7e55919' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\aditi\gujarat GT\gt_points1.shp
# Executing 68st file
# Table 'NCFCCrop20160218115847_502e3555' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\aditi\gujarat GT\NCFCCrop20160218115847.shp
# Executing 69st file
# Table 'hoshiapurblck_utm_d7b8fe37' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\aditi\hoshiarpur_GIS\hoshiapurblck_utm.shp
# Executing 70st file
# Table 'hoshiapur_villages_5591a6ce' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\aditi\hoshiarpur_GIS\hoshiapur_villages.shp
# Executing 71st file
# Table 'hoshiarpur_c47b82c1' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\aditi\hoshiarpur_GIS\hoshiarpur.shp
# Executing 72st file
# Table 'hoshiarpur_road_b0b78192' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\aditi\hoshiarpur_GIS\hoshiarpur_road.shp
# Executing 73st file
# Table 'Hoshiyarpur_age_63a71be3' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\aditi\hoshiarpur_GIS\Hoshiyarpur_age.shp
# Executing 74st file
# Table 'hoshiyarpur_veg2_6cc4c2e6' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\aditi\hoshiarpur_GIS\hoshiyarpur_veg2.shp
# Executing 75st file
# Table 'Hosh_GT_55a1e7cb' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\aditi\hoshiarpur_GIS\Hosh_GT.shp
# Executing 76st file
# Table 'haryana_distt_utm_f1062206' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\aditi\yamunagar indent\haryana_distt_utm.shp
# Executing 77st file
# Table '14-17GT2017_f1ada598' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\andhrapradesh telenagana chilli 2016_17\14-17GT2017.shp
# Executing 78st file
# Table '14-17GT2017_3601b6db' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\andhrapradesh telenagana chilli 2016_17\AP_TN Dist shp\14-17GT2017.shp
# Executing 79st file
# Table 'Cadappa_ae79fe3a' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\andhrapradesh telenagana chilli 2016_17\AP_TN Dist shp\Cadappa.shp
# Executing 80st file
# Table 'chittoor_dist_9713e6b8' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\andhrapradesh telenagana chilli 2016_17\AP_TN Dist shp\chittoor_dist.shp
# Executing 81st file
# Table 'gt_oct_16_67841ea8' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\andhrapradesh telenagana chilli 2016_17\AP_TN Dist shp\gt_oct_16.shp
# Executing 82st file
# Table 'Guntur_2987a863' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\andhrapradesh telenagana chilli 2016_17\AP_TN Dist shp\Guntur.shp
# Executing 83st file
# Table 'Khammam_710ff24c' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\andhrapradesh telenagana chilli 2016_17\AP_TN Dist shp\Khammam.shp
# Executing 84st file
# Table 'Khandwa_District_75e71956' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\andhrapradesh telenagana chilli 2016_17\AP_TN Dist shp\Khandwa_District.shp
# Executing 85st file
# Table 'Krishna_745ba0d6' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\andhrapradesh telenagana chilli 2016_17\AP_TN Dist shp\Krishna.shp
# Executing 86st file
# Table 'Kurnool_45945e60' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\andhrapradesh telenagana chilli 2016_17\AP_TN Dist shp\Kurnool.shp
# Executing 87st file
# Table 'Mahbubnagar_c6d4d5b9' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\andhrapradesh telenagana chilli 2016_17\AP_TN Dist shp\Mahbubnagar.shp
# Executing 88st file
# Table 'Prakasam_8ff470b4' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\andhrapradesh telenagana chilli 2016_17\AP_TN Dist shp\Prakasam.shp
# Executing 89st file
# Table 'Rangareddi_9bcc0e9d' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\andhrapradesh telenagana chilli 2016_17\AP_TN Dist shp\Rangareddi.shp
# Executing 90st file
# Table 'shamali_road_c86aebbd' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\andhrapradesh telenagana chilli 2016_17\AP_TN Dist shp\shamali_road.shp
# Executing 91st file
# Table 'shamali_village_334f8f8d' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\andhrapradesh telenagana chilli 2016_17\AP_TN Dist shp\shamali_village.shp
# Executing 92st file
# Table 'sultanpur_road_09e54610' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\andhrapradesh telenagana chilli 2016_17\AP_TN Dist shp\sultanpur_road.shp
# Executing 93st file
# Table 'sultanpur_village_3ef2aedc' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\andhrapradesh telenagana chilli 2016_17\AP_TN Dist shp\sultanpur_village.shp
# Executing 94st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\CHAMAN\\andhrapradesh telenagana chilli 2016_17\\AP_TN Dist shp\\Tel_14_TO_17FEB_GT' \\192.168.1.151\ncfc_data3\CHAMAN\andhrapradesh telenagana chilli 2016_17\AP_TN Dist shp\Tel_14_TO_17FEB_GT.zip\shape/NCFCCrop2017022184735.shp
# Executing 95st file
# Table 'Vishakhapatnam_bc9f5090' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\andhrapradesh telenagana chilli 2016_17\AP_TN Dist shp\Vishakhapatnam.shp
# Executing 96st file
# Table 'Warangal_c932f56c' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\andhrapradesh telenagana chilli 2016_17\AP_TN Dist shp\Warangal.shp
# Executing 97st file
# [Errno 13] Permission denied: '\\\\192.168.1.151\\ncfc_data3\\CHAMAN\\andhrapradesh telenagana chilli 2016_17\\AP_TN Dist shp\\gt_feb2017\\Tel_14_TO_17FEB_GT' \\192.168.1.151\ncfc_data3\CHAMAN\andhrapradesh telenagana chilli 2016_17\AP_TN Dist shp\gt_feb2017\Tel_14_TO_17FEB_GT.zip\shape/NCFCCrop2017022184735.shp
# Executing 98st file
# Table 'NCFCCrop2017022184735_07a39e4d' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\andhrapradesh telenagana chilli 2016_17\AP_TN Dist shp\gt_feb2017\Tel_14_TO_17FEB_GT\shape\NCFCCrop2017022184735.shp
# Executing 99st file
# Table 'NCFCCrop20170102104820_8816885e' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\andhrapradesh telenagana chilli 2016_17\Bihar chilli_tomato\NCFCCrop20170102104820\shape\NCFCCrop20170102104820.shp
# Executing 100st file
# Table 'NCFCCrop2017022184735_e1e8979e' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\andhrapradesh telenagana chilli 2016_17\shape\NCFCCrop2017022184735.shp
# Executing 101st file
# C:\Users\user\miniconda3\envs\kdss\lib\site-packages\geopandas\io\sql.py:415: UserWarning: Could not parse CRS from the GeoDataFrame. Inserting data without defined CRS.
#   srid = _get_srid_from_crs(gdf)
# Table 'contour_66f0ea48' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\Basic\3D Analyst_Data\contour.shp
# Executing 102st file
# Table 'Cavesurvey_93f5e675' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\Basic\3D Analyst_Data\Cavedata\Cavesurvey.shp
# Executing 103st file
# Table 'solidmodel_446d11c0' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\Basic\3D Analyst_Data\Cavedata\solidmodel.shp
# Executing 104st file
# Table 'PG1_a9441c06' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\Basic\3D Analyst_Data\ProfileGraphData\PG1.shp
# Executing 105st file
# Table 'brklines_ca911f68' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\Basic\3D Analyst_Data\Terraindata\brklines.shp
# Executing 106st file
# C:\Users\user\miniconda3\envs\kdss\lib\site-packages\geopandas\io\sql.py:415: UserWarning: Could not parse CRS from the GeoDataFrame. Inserting data without defined CRS.
#   srid = _get_srid_from_crs(gdf)
# Table 'railroad_1b8d22b6' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\Basic\3D Analyst_Data\Terraindata\railroad.shp
# Executing 107st file
# Table 'smclp_e0f0c6f9' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\Basic\3D Analyst_Data\Terraindata\smclp.shp
# Executing 108st file
# Table 'roads_5e25efc9' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\Basic\3D Analyst_Data\Town\roads.shp
# Executing 109st file
# C:\Users\user\miniconda3\envs\kdss\lib\site-packages\geopandas\io\sql.py:415: UserWarning: Could not parse CRS from the GeoDataFrame. Inserting data without defined CRS.
#   srid = _get_srid_from_crs(gdf)
# C:\Users\user\miniconda3\envs\kdss\lib\site-packages\geopandas\io\sql.py:415: UserWarning: Could not parse CRS from the GeoDataFrame. Inserting data without defined CRS.
#   srid = _get_srid_from_crs(gdf)
# Table 'PG1_f326d441' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\Basic\ProfileGraphData\PG1.shp
# Executing 110st file
# Table 'PG2_57370fda' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\Basic\ProfileGraphData\PG2.shp
# Executing 111st file
# C:\Users\user\miniconda3\envs\kdss\lib\site-packages\geopandas\io\sql.py:415: UserWarning: Could not parse CRS from the GeoDataFrame. Inserting data without defined CRS.
#   srid = _get_srid_from_crs(gdf)
# Table 'PG3_e1798f0c' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\Basic\ProfileGraphData\PG3.shp
# Executing 112st file
# Table 'PG4_fc5a1841' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\Basic\ProfileGraphData\PG4.shp
# Executing 113st file
# C:\Users\user\miniconda3\envs\kdss\lib\site-packages\geopandas\io\sql.py:415: UserWarning: Could not parse CRS from the GeoDataFrame. Inserting data without defined CRS.
#   srid = _get_srid_from_crs(gdf)
# C:\Users\user\miniconda3\envs\kdss\lib\site-packages\geopandas\io\sql.py:415: UserWarning: Could not parse CRS from the GeoDataFrame. Inserting data without defined CRS.
#   srid = _get_srid_from_crs(gdf)
# Table 'PG5_062a6026' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\Basic\ProfileGraphData\PG5.shp
# Executing 114st file
# Table 'PG6_3ad9a3fe' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\Basic\ProfileGraphData\PG6.shp
# Executing 115st file
# C:\Users\user\miniconda3\envs\kdss\lib\site-packages\geopandas\io\sql.py:415: UserWarning: Could not parse CRS from the GeoDataFrame. Inserting data without defined CRS.
#   srid = _get_srid_from_crs(gdf)
# Table 'blkgrp_77b2c18e' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\esri\ARC1\Florida\blkgrp.shp
# Executing 116st file
# Table 'FL_DayCareCenters_a807e2de' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\esri\ARC1\Florida\FL_DayCareCenters.shp
# Executing 117st file
# Table 'FL_NursingHomes_80988307' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\esri\ARC1\Florida\FL_NursingHomes.shp
# Executing 118st file
# Table 'hcane_84cab5d6' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\esri\ARC1\Florida\hcane.shp
# Executing 119st file
# Table 'Majrds_ab1ad43b' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\esri\ARC1\Florida\Majrds.shp
# Executing 120st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\CHAMAN\\ArcGIS_Training Manual\\esri\\ARC1\\Florida\\StormSurge' \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\esri\ARC1\Florida\StormSurge.zip\Cat1.shp
# Executing 121st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\CHAMAN\\ArcGIS_Training Manual\\esri\\ARC1\\Florida\\StormSurge' \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\esri\ARC1\Florida\StormSurge.zip\Cat2.shp
# Executing 122st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\CHAMAN\\ArcGIS_Training Manual\\esri\\ARC1\\Florida\\StormSurge' \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\esri\ARC1\Florida\StormSurge.zip\Cat3.shp
# Executing 123st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\CHAMAN\\ArcGIS_Training Manual\\esri\\ARC1\\Florida\\StormSurge' \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\esri\ARC1\Florida\StormSurge.zip\Cat4_5.shp
# Executing 124st file
# Table 'FL_Counties_3569b36d' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\esri\ARC1\OnlineFiles\FL_Counties.shp
# Executing 125st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\CHAMAN\\ArcGIS_Training Manual\\esri\\ARC1\\OnlineFiles\\ParkingFacilities' \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\esri\ARC1\OnlineFiles\ParkingFacilities.zip\ParkingFacilities.shp
# Executing 126st file
# Table 'Category3_e96d8928' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\esri\ARC1\Results\Lesson09\Category3.shp
# Executing 127st file
# Table 'LeeHospitals_5d03f8b1' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\esri\ARC1\Results\Lesson09\LeeHospitals.shp
# Executing 128st file
# Table 'WilsonCrimes_8e15488e' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\esri\ARC1\WilsonNC\WilsonCrimes.shp
# Executing 129st file
# C:\Users\user\miniconda3\envs\kdss\lib\site-packages\geopandas\io\sql.py:415: UserWarning: Could not parse CRS from the GeoDataFrame. Inserting data without defined CRS.
#   srid = _get_srid_from_crs(gdf)
# Table 'WilsonLots_30107d32' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\esri\ARC1\WilsonNC\WilsonLots.shp
# Executing 130st file
# Table 'wilson_cityb_8d4f0323' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\esri\ARC1\WilsonNC\wilson_cityb.shp
# Executing 131st file
# Table 'Wilson_Recareas_0b950de1' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\esri\ARC1\WilsonNC\Wilson_Recareas.shp
# Executing 132st file
# Table 'Wilson_Streets_f7f5afdc' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\esri\ARC1\WilsonNC\Wilson_Streets.shp
# Executing 133st file
# [Errno 13] Permission denied: '\\\\192.168.1.151\\ncfc_data3\\CHAMAN\\Barabanki\\NCFCCrop2016061383541' \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\NCFCCrop2016061383541.zip\shape/NCFCCrop2016061383541.shp
# Executing 134st file
# Table 'BARABANKIAMENITY_2f7eaf68' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\Barabanki_vector\BARABANKIAMENITY.shp
# Executing 135st file
# Table 'BARABANKIBLOCK_8f2f5061' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\Barabanki_vector\BARABANKIBLOCK.shp
# Executing 136st file
# Table 'BARABANKICANAL_abe03fa3' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\Barabanki_vector\BARABANKICANAL.shp
# Executing 137st file
# Table 'BARABANKIDEMOGRAPHY_4ed293b8' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\Barabanki_vector\BARABANKIDEMOGRAPHY.shp
# Executing 138st file
# Table 'BARABANKIDISTRICT_ede4e99f' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\Barabanki_vector\BARABANKIDISTRICT.shp
# Executing 139st file
# Table 'BARABANKIDRAINL_791ed809' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\Barabanki_vector\BARABANKIDRAINL.shp
# Executing 140st file
# Table 'BARABANKIDRAINP_79cae48c' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\Barabanki_vector\BARABANKIDRAINP.shp
# Executing 141st file
# Table 'BARABANKIFOREST_38a20e62' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\Barabanki_vector\BARABANKIFOREST.shp
# Executing 142st file
# Table 'BARABANKIGEOM_d782ef90' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\Barabanki_vector\BARABANKIGEOM.shp
# Executing 143st file
# Table 'BARABANKIGWATER_a812d0b6' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\Barabanki_vector\BARABANKIGWATER.shp
# Executing 144st file
# Table 'BARABANKILITHO_13fa1150' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\Barabanki_vector\BARABANKILITHO.shp
# Executing 145st file
# Table 'BARABANKILULC_c7bd22d1' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\Barabanki_vector\BARABANKILULC.shp
# Executing 146st file
# Table 'BARABANKIRAIL_c7749d51' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\Barabanki_vector\BARABANKIRAIL.shp
# Executing 147st file
# Table 'BARABANKIROAD_bb80590c' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\Barabanki_vector\BARABANKIROAD.shp
# Executing 148st file
# Table 'BARABANKISETA_1d9363f4' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\Barabanki_vector\BARABANKISETA.shp
# Executing 149st file
# Table 'BARABANKISETTLEP_b8b69aed' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\Barabanki_vector\BARABANKISETTLEP.shp
# Executing 150st file
# Table 'BARABANKISOIL_3aaa98ff' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\Barabanki_vector\BARABANKISOIL.shp
# Executing 151st file
# Table 'BARABANKISTRU_de6fc59d' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\Barabanki_vector\BARABANKISTRU.shp
# Executing 152st file
# Table 'BARABANKITALUK_55329ff7' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\Barabanki_vector\BARABANKITALUK.shp
# Executing 153st file
# Table 'BARABANKIVILL_0b0bad0b' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\Barabanki_vector\BARABANKIVILL.shp
# Executing 154st file
# Table 'BARABANKIWELL_ab4e07cd' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\Barabanki_vector\BARABANKIWELL.shp
# Executing 155st file
# Table 'BARABANKIWSHED_9b6b9d2a' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\Barabanki_vector\BARABANKIWSHED.shp
# Executing 156st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\CHAMAN\\Barabanki\\Barabanki_vector\\Barabanki_vector' \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\Barabanki_vector\Barabanki_vector.zip\BARABANKIDISTRICT.shp
# Executing 157st file
# Table 'New_Shapefile_23dd99af' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\Barabanki_vector\New_Shapefile.shp
# Executing 158st file
# Table 'NCFCCrop2016061383541_5543b92b' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\NCFCCrop2016061383541\shape\NCFCCrop2016061383541.shp
# Executing 159st file
# Table 'Barabanki_e9cca292' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\up_vectors\Barabanki.shp
# Executing 160st file
# Table 'gt_plan_f4ed8284' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\up_vectors\gt_plan.shp
# Executing 161st file
# Table 'lucknow_barabanki_1634bccb' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\up_vectors\lucknow_barabanki.shp
# Executing 162st file
# Table 'lucknow_barabanki_block_e9b12b4c' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\up_vectors\lucknow_barabanki_block.shp
# Executing 163st file
# Table 'lucknow_barabanki_road_0d84c9a4' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\up_vectors\lucknow_barabanki_road.shp
# Executing 164st file
# Table 'lucknow_barabanki_vill_77894b8e' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\up_vectors\lucknow_barabanki_vill.shp
# Executing 165st file
# Table 'up_districts_73bddbf3' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\Barabanki\up_vectors\up_districts.shp
# Executing 166st file
# Table 'darbhanga_upload_ac6592bb' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan bihar mango\darbhanga_upload.shp
# Executing 167st file
# Table 'echamparan_upload_3c56faec' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan bihar mango\echamparan_upload.shp
# Executing 168st file
# Table 'sitamarhii_upload_226f9052' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan bihar mango\sitamarhii_upload.shp
# Executing 169st file
# Table 'vaishali_upload_ddc2fb89' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan bihar mango\vaishali_upload.shp
# Executing 170st file
# Table 'wchamparan_upload_2850cb25' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan bihar mango\wchamparan_upload.shp
# Executing 171st file
# Table 'firozepur_citrus_final_9b9228b4' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan citrus layers\firozepur_citrus_final.shp
# Executing 172st file
# Table 'firozepur_citrus_final_utm_c76967ea' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan citrus layers\firozepur_citrus_final_utm.shp
# Executing 173st file
# Table 'muktsar_citrus_final_a03cb807' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan citrus layers\muktsar_citrus_final.shp
# Executing 174st file
# Table 'citrus_hoshiarpur_final_d6b94efc' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan citrus layers\bhuvan punjab citrus\citrus_hoshiarpur_final.shp
# Executing 175st file
# Table 'firozepur_citrus_final_7713cbcf' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan citrus layers\bhuvan punjab citrus\firozepur_citrus_final.shp
# Executing 176st file
# Table 'muktsar_citrus_final_dc564329' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan citrus layers\bhuvan punjab citrus\muktsar_citrus_final.shp
# Executing 177st file
# Table 'citrus_hoshiarpur_final_ae5d24fe' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan citrus layers\bhuvan punjab citrus\bhuvan hoshiarpur citrus\bhuvan hoshiarpur citrus\citrus_hoshiarpur_final.shp
# Executing 178st file
# Table 'gandhinagar_bhuvan_d753def6' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan citrus layers\gandhinagar_bhuvan\gandhinagar_bhuvan.shp
# Executing 179st file
# Table 'bulandshahr_utm_4276b9c5' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan mango\bulandshahr_utm.shp
# Executing 180st file
# Table 'darbhanga_upload_025823ae' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan mango\darbhanga_upload.shp
# Executing 181st file
# Table 'darbhanga_utm_fd21ffcc' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan mango\darbhanga_utm.shp
# Executing 182st file
# Table 'echamparan_upload_310be9f3' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan mango\echamparan_upload.shp
# Executing 183st file
# Table 'echamparan_utm_287e1e20' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan mango\echamparan_utm.shp
# Executing 184st file
# Table 'hardoi_utm_ea7530d9' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan mango\hardoi_utm.shp
# Executing 185st file
# Table 'meerut_utm_04a19d2d' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan mango\meerut_utm.shp
# Executing 186st file
# Table 'sitamarhii_upload_31f15384' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan mango\sitamarhii_upload.shp
# Executing 187st file
# Table 'sitamarhi_utm_8b714487' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan mango\sitamarhi_utm.shp
# Executing 188st file
# Table 'sitapur_utm_95d55df0' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan mango\sitapur_utm.shp
# Executing 189st file
# Table 'vaishali_upload_07fde83f' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan mango\vaishali_upload.shp
# Executing 190st file
# Table 'vaishali_utm_d22406fe' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan mango\vaishali_utm.shp
# Executing 191st file
# Table 'wchamparan_upload_086bcefd' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan mango\wchamparan_upload.shp
# Executing 192st file
# Table 'wchamparan_utm_cfa784ff' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan mango\wchamparan_utm.shp
# Executing 193st file
# Table '`saharanpur_utm_fbb3771b' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan mango\`saharanpur_utm.shp
# Executing 194st file
# Table 'Bulandshahr_mango_3a4103c5' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan uttar pradesh _mango\Bulandshahr_mango.shp
# Executing 195st file
# Table 'hardoi_mango_409b8454' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan uttar pradesh _mango\hardoi_mango.shp
# Executing 196st file
# Table 'Meerut_mango_8e37bdb3' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan uttar pradesh _mango\Meerut_mango.shp
# Executing 197st file
# Table 'saharanpur_mango_da517c1c' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan uttar pradesh _mango\saharanpur_mango.shp
# Executing 198st file
# Table 'sitapur_mango_245824c6' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\bhuvan uttar pradesh _mango\sitapur_mango.shp
# Executing 199st file
# Table 'lakhisasrai_1e683913' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\BIHAR ERDAS16\bihar study area shape\lakhisasrai.shp
# Executing 200st file
# Table 'nalanda tahsil_4dc8a0ac' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\BIHAR ERDAS16\bihar study area shape\nalanda tahsil.shp
# Executing 201st file
# Table 'patna tahsil_5ea2bd05' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\BIHAR ERDAS16\bihar study area shape\patna tahsil.shp
# Executing 202st file
# Table 'patna tahsil1_16e45877' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\BIHAR ERDAS16\bihar study area shape\patna tahsil1.shp
# Executing 203st file
# Table 'repro_indadm3_af9cbd04' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\BIHAR ERDAS16\bihar study area shape\repro_indadm3.shp
# Executing 204st file
# Table 'sheikhapura_a8e4627e' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\BIHAR ERDAS16\bihar study area shape\sheikhapura.shp
# Executing 205st file
# Table 'study_area_bihar_3ea509aa' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\BIHAR ERDAS16\bihar study area shape\study_area_bihar.shp
# Executing 206st file
# Table 'india district_b7d13ae7' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\BIHAR ERDAS16\India-vector cover\india district.shp
# Executing 207st file
# Table 'karnataka study area_1d87f606' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\BIHAR ERDAS16\India-vector cover\karnataka study area.shp
# Executing 208st file
# Table 'nalanda district_fe80167d' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\BIHAR ERDAS16\India-vector cover\nalanda district.shp
# Executing 209st file
# Table 'patna district_f02414dd' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\BIHAR ERDAS16\India-vector cover\patna district.shp
# Executing 210st file
# Table 'utm_polygon_12979d62' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\BIHAR ERDAS16\India-vector cover\utm_polygon.shp
# Executing 211st file
# Table 'chhindwara_2952bd21' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\chamanDocuments\CHAMAN districts\chhindwara.shp
# Executing 212st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\CHAMAN\\chamanDocuments\\CHAMAN districts\\chindwara' \\192.168.1.151\ncfc_data3\CHAMAN\chamanDocuments\CHAMAN districts\chindwara.zip\chhindwara.shp
# Executing 213st file
# Table 'chittoor_5b1f4b9e' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\chamanDocuments\CHAMAN districts\chittoor.shp
# Executing 214st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\CHAMAN\\chamanDocuments\\CHAMAN districts\\dharbanga' \\192.168.1.151\ncfc_data3\CHAMAN\chamanDocuments\CHAMAN districts\dharbanga.zip\dharbhanga.shp
# Executing 215st file
# Table 'dharbhanga_3301aac7' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\chamanDocuments\CHAMAN districts\dharbhanga.shp
# Executing 216st file
# Table 'Kolar_dee7f1a4' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\chamanDocuments\CHAMAN districts\Kolar.shp
# Executing 217st file
# Table 'kurnool_03e26c31' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\chamanDocuments\CHAMAN districts\kurnool.shp
# Executing 218st file
# Table 'nalgonda_7947e42a' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\chamanDocuments\CHAMAN districts\nalgonda.shp
# Executing 219st file
# Table 'nashik_a824081b' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\chamanDocuments\CHAMAN districts\nashik.shp
# Executing 220st file
# Table 'selected_district_a9b8ffd9' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\chamanDocuments\CHAMAN districts\selected_district.shp
# Executing 221st file
# Table 'Shahranpur_a3883914' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\chamanDocuments\CHAMAN districts\Shahranpur.shp
# Executing 222st file
# [Errno 2] No such file or directory: '\\\\192.168.1.151\\ncfc_data3\\CHAMAN\\chamanDocuments\\chaman_brochure+report\\NCFCCrop20180404120254' \\192.168.1.151\ncfc_data3\CHAMAN\chamanDocuments\chaman_brochure+report\NCFCCrop20180404120254.zip\shape/NCFCCrop20180404120254.shp
# Executing 223st file
# Table 'CHAMAN_districts_66bfc3a1' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\chamanDocuments\chaman_brochure+report\chaman district\CHAMAN_districts.shp
# Executing 224st file
# Table 'Bhagalpur_upload_d1b6f521' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\bhuvan_upload\Bihar\Bhagalpur\Bhagalpur_upload.shp
# Executing 225st file
# Table 'navsari_upload_a1f43308' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\bhuvan_upload\Gujarat\Navsari\navsari_upload.shp
# Executing 226st file
# Table 'Surat_upload_11274353' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\bhuvan_upload\Gujarat\Surat\Surat_upload.shp
# Executing 227st file
# Table 'Valsad_upload_c71f59ab' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\bhuvan_upload\Gujarat\Valsad\Valsad_upload.shp
# Executing 228st file
# Table 'Faizabad_upload_acc4dd8b' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\bhuvan_upload\Uttar Pradesh\Faizabad\Faizabad_upload.shp
# Executing 229st file
# Table 'Lucknow_upload_f460b1c6' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\bhuvan_upload\Uttar Pradesh\Lucknow\Lucknow_upload.shp
# Executing 230st file
# Table 'Varanasi_upload_1c7eedfe' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\bhuvan_upload\Uttar Pradesh\Varanasi\Varanasi_upload.shp
# Executing 231st file
# Table 'Final_chaman_gt_4f0f770b' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\CHAMAN_MPRSAC_GT_Points\Final_chaman_gt.shp
# Executing 232st file
# Table 'Final_chaman_gt1_2868d707' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\CHAMAN_MPRSAC_GT_Points\Final_chaman_gt1.shp
# Executing 233st file
# Table 'Final_chaman_gt_proj_64bbc26c' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\CHAMAN_MPRSAC_GT_Points\Final_chaman_gt_proj.shp
# Executing 234st file
# Table 'Final_chaman_gt_repr_3450b8dd' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\CHAMAN_MPRSAC_GT_Points\Final_chaman_gt_repr.shp
# Executing 235st file
# Table 'Final_chaman_gt_repr1_eb4afb99' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\CHAMAN_MPRSAC_GT_Points\Final_chaman_gt_repr1.shp
# Executing 236st file
# Table 'Ahmedabad_Citrus_5a9a3751' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Citrus\Gujarat\Ahmedabad\Ahmedabad_Citrus.shp
# Executing 237st file
# Table 'bhavnagar_bhuvan_23b1b760' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Citrus\Gujarat\Bhavnagar\bhavnagar_bhuvan.shp
# Executing 238st file
# Table 'gandhinagar_bhuvan_738fbb6d' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Citrus\Gujarat\Gandhinagar\gandhinagar_bhuvan.shp
# Executing 239st file
# Table 'Mehsana_citrus_1f0f55d0' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Citrus\Gujarat\Mehsana\Mehsana_citrus.shp
# Executing 240st file
# Table 'agar_bhuvan_597c4647' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Citrus\Madhya_Pradesh\Agar_Malwa\agar_bhuvan.shp
# Executing 241st file
# Table 'chhindwara_bhuvan_6114058b' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Citrus\Madhya_Pradesh\Chindwara\chhindwara_bhuvan.shp
# Executing 242st file
# Table 'mandsaur_bhuvan_4e435c46' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Citrus\Madhya_Pradesh\Mandsaur\mandsaur_bhuvan.shp
# Executing 243st file
# Table 'shajapur_bhuvan_d9120a93' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Citrus\Madhya_Pradesh\Shajapur\shajapur_bhuvan.shp
# Executing 244st file
# Table 'firozepur_citrus_final_7ead869b' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Citrus\Punjab\Firozepur\firozepur_citrus_final.shp
# Executing 245st file
# Table 'citrus_hoshiarpur_final_421fdd95' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Citrus\Punjab\Hoshiarpur\citrus_hoshiarpur_final.shp
# Executing 246st file
# Table 'muktsar_citrus_final_2567b5e4' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Citrus\Punjab\Muktsar\muktsar_citrus_final.shp
# Executing 247st file
# Table 'Bhagalpur_upload_f9200f01' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Mango\Bihar\Bhagalpur\Bhagalpur_upload.shp
# Executing 248st file
# Table 'darbhanga_upload_8d6becd4' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Mango\Bihar\Darbhanga\darbhanga_upload.shp
# Executing 249st file
# Table 'echamparan_upload_1b336432' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Mango\Bihar\East_Champaran\echamparan_upload.shp
# Executing 250st file
# Table 'sitamarhii_upload_5ff4f95f' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Mango\Bihar\Sitamarhi\sitamarhii_upload.shp
# Executing 251st file
# Table 'vaishali_upload_f8cfe3c6' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Mango\Bihar\Vaishali\vaishali_upload.shp
# Executing 252st file
# Table 'wchamparan_upload_45553037' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Mango\Bihar\West_Champaran\wchamparan_upload.shp
# Executing 253st file
# Table 'bhavnagar_mngo_4e5eb825' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Mango\Gujarat\Bhavnagar\bhavnagar_mango\bhavnagar_mngo.shp
# Executing 254st file
# Table 'final_junagarh_mango_Project_44b75a9a' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Mango\Gujarat\Junagadh\final_junagarh_mango_Project.shp
# Executing 255st file
# Table 'navsari_upload_bdccddf0' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Mango\Gujarat\Navsari\navsari_upload.shp
# Executing 256st file
# Table 'Surat_upload_ffeced8b' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Mango\Gujarat\Surat\Surat_upload.shp
# Executing 257st file
# Table 'Valsad_upload_9903b45d' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Mango\Gujarat\Valsad\Valsad_upload.shp
# Executing 258st file
# Table 'Bulandshahr_mango_b10d691d' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Mango\Uttar_Pradesh\Bulandshahr\Bulandshahr_mango.shp
# Executing 259st file
# Table 'Faizabad_upload_96d78ecc' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Mango\Uttar_Pradesh\Faizabad\Faizabad_upload.shp
# Executing 260st file
# Table 'hardoi_mango_c9042f1e' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Mango\Uttar_Pradesh\Hardoi\hardoi_mango.shp
# Executing 261st file
# Table 'Lucknow_upload_cb625153' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Mango\Uttar_Pradesh\Lucknow\Lucknow_upload.shp
# Executing 262st file
# Table 'Meerut_mango_73cf2cf0' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Mango\Uttar_Pradesh\Meerut\Meerut_mango.shp
# Executing 263st file
# Table 'saharanpur_mango_92bd0c47' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Mango\Uttar_Pradesh\Saharanpur\saharanpur_mango.shp
# Executing 264st file
# Table 'sitapur_mango_07b7a4eb' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Mango\Uttar_Pradesh\Sitapur\sitapur_mango.shp
# Executing 265st file
# Table 'Varanasi_upload_f4c880de' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\CHAMAN_BHUVAN\Mango\Uttar_Pradesh\Varanasi\Varanasi_upload.shp
# Executing 266st file
# Table 'coriander_b533f085' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\coriander landsat\kota coriander\coriander.shp
# Executing 267st file
# Table 'coriander_gt_19defb5c' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\coriander landsat\kota coriander\coriander_gt.shp
# Executing 268st file
# ...
# Executing 1630st file
# Table 'KAUSHAMBIWELL_35b2ca79' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Kaushambi\KAUSHAMBIWELL.shp
# Executing 1631st file
# Table 'KUSHINAGARAMENITY_c688c2b4' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Kushinagar\KUSHINAGARAMENITY.shp
# Executing 1632st file
# Table 'KUSHINAGARBLOCK_e1b0f12c' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Kushinagar\KUSHINAGARBLOCK.shp
# Executing 1633st file
# Table 'KUSHINAGARCANAL_dbd2baac' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Kushinagar\KUSHINAGARCANAL.shp
# Executing 1634st file
# Table 'KUSHINAGARDEMOGRAPHY_ae987096' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Kushinagar\KUSHINAGARDEMOGRAPHY.shp
# Executing 1635st file
# Table 'KUSHINAGARDISTRICT_426e6f9a' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Kushinagar\KUSHINAGARDISTRICT.shp
# Executing 1636st file
# Table 'KUSHINAGARDRAINL_e2211103' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Kushinagar\KUSHINAGARDRAINL.shp
# Executing 1637st file
# Table 'KUSHINAGARDRAINP_94223ae5' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Kushinagar\KUSHINAGARDRAINP.shp
# Executing 1638st file
# Table 'KUSHINAGARFOREST_7cad4054' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Kushinagar\KUSHINAGARFOREST.shp
# Executing 1639st file
# Table 'KUSHINAGARGEOM_8640cc63' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Kushinagar\KUSHINAGARGEOM.shp
# Executing 1640st file
# Table 'KUSHINAGARGWATER_e4102ba2' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Kushinagar\KUSHINAGARGWATER.shp
# Executing 1641st file
# Table 'KUSHINAGARLITHO_624cdf33' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Kushinagar\KUSHINAGARLITHO.shp
# Executing 1642st file
# Table 'KUSHINAGARLULC_fb46fa76' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Kushinagar\KUSHINAGARLULC.shp
# Executing 1643st file
# Table 'KUSHINAGARRAIL_cc553f40' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Kushinagar\KUSHINAGARRAIL.shp
# Executing 1644st file
# Table 'KUSHINAGARROAD_048555ac' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Kushinagar\KUSHINAGARROAD.shp
# Executing 1645st file
# Table 'KUSHINAGARSETA_51551b3a' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Kushinagar\KUSHINAGARSETA.shp
# Executing 1646st file
# Table 'KUSHINAGARSETTLEP_409de25d' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Kushinagar\KUSHINAGARSETTLEP.shp
# Executing 1647st file
# Table 'KUSHINAGARSOIL_2424ee3c' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Kushinagar\KUSHINAGARSOIL.shp
# Executing 1648st file
# Table 'KUSHINAGARSTRU_2474a894' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Kushinagar\KUSHINAGARSTRU.shp
# Executing 1649st file
# Table 'KUSHINAGARTALUK_ba5df0a7' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Kushinagar\KUSHINAGARTALUK.shp
# Executing 1650st file
# Table 'KUSHINAGARVILL_e0e3a748' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Kushinagar\KUSHINAGARVILL.shp
# Executing 1651st file
# Table 'KUSHINAGARWELL_aea4aeec' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Kushinagar\KUSHINAGARWELL.shp
# Executing 1652st file
# Table 'KUSHINAGARWSHED_14e11c75' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Kushinagar\KUSHINAGARWSHED.shp
# Executing 1653st file
# Table 'LAKHIMPURKHERIAMENITY_39b8ff8e' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lakhimpur Kheri\LAKHIMPURKHERIAMENITY.shp
# Executing 1654st file
# Table 'LAKHIMPURKHERIBLOCK_0a5669aa' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lakhimpur Kheri\LAKHIMPURKHERIBLOCK.shp
# Executing 1655st file
# Table 'LAKHIMPURKHERICANAL_26f82ee4' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lakhimpur Kheri\LAKHIMPURKHERICANAL.shp
# Executing 1656st file
# Table 'LAKHIMPURKHERIDEMOGRAPHY_12963814' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lakhimpur Kheri\LAKHIMPURKHERIDEMOGRAPHY.shp
# Executing 1657st file
# Table 'LAKHIMPURKHERIDISTRICT_29fe8056' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lakhimpur Kheri\LAKHIMPURKHERIDISTRICT.shp
# Executing 1658st file
# Table 'LAKHIMPURKHERIDRAINL_756bbf77' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lakhimpur Kheri\LAKHIMPURKHERIDRAINL.shp
# Executing 1659st file
# Table 'LAKHIMPURKHERIDRAIP_2b21105d' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lakhimpur Kheri\LAKHIMPURKHERIDRAIP.shp
# Executing 1660st file
# Table 'LAKHIMPURKHERIFOREST_7aa4ca32' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lakhimpur Kheri\LAKHIMPURKHERIFOREST.shp
# Executing 1661st file
# Table 'LAKHIMPURKHERIGEOM_eb9fc7d6' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lakhimpur Kheri\LAKHIMPURKHERIGEOM.shp
# Executing 1662st file
# Table 'LAKHIMPURKHERIGWATER_52669ca8' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lakhimpur Kheri\LAKHIMPURKHERIGWATER.shp
# Executing 1663st file
# Table 'LAKHIMPURKHERILITHO_dd59e9e8' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lakhimpur Kheri\LAKHIMPURKHERILITHO.shp
# Executing 1664st file
# Table 'LAKHIMPURKHERILULC_99bafae4' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lakhimpur Kheri\LAKHIMPURKHERILULC.shp
# Executing 1665st file
# Table 'LAKHIMPURKHERIRAIL_30371898' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lakhimpur Kheri\LAKHIMPURKHERIRAIL.shp
# Executing 1666st file
# Table 'LAKHIMPURKHERIROAD_84c0051a' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lakhimpur Kheri\LAKHIMPURKHERIROAD.shp
# Executing 1667st file
# Table 'LAKHIMPURKHERISETA_635bcc2d' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lakhimpur Kheri\LAKHIMPURKHERISETA.shp
# Executing 1668st file
# Table 'LAKHIMPURKHERISETTLEP_6c17703b' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lakhimpur Kheri\LAKHIMPURKHERISETTLEP.shp
# Executing 1669st file
# Table 'LAKHIMPURKHERISOIL_ec7b6f25' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lakhimpur Kheri\LAKHIMPURKHERISOIL.shp
# Executing 1670st file
# Table 'LAKHIMPURKHERISTRU_0e6af0a9' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lakhimpur Kheri\LAKHIMPURKHERISTRU.shp
# Executing 1671st file
# Table 'LAKHIMPURKHERITALUK_c5b07f01' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lakhimpur Kheri\LAKHIMPURKHERITALUK.shp
# Executing 1672st file
# Table 'LAKHIMPURKHERIVILL_febfba3b' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lakhimpur Kheri\LAKHIMPURKHERIVILL.shp
# Executing 1673st file
# Table 'LAKHIMPURKHERIWELL_c7084854' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lakhimpur Kheri\LAKHIMPURKHERIWELL.shp
# Executing 1674st file
# Table 'LAKHIMPURKHERIWSHED_6f29bf9d' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lakhimpur Kheri\LAKHIMPURKHERIWSHED.shp
# Executing 1675st file
# Table 'LALITPURAMENITY_5197e803' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lalitpur\LALITPURAMENITY.shp
# Executing 1676st file
# Table 'LALITPURBLOCK_382520be' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lalitpur\LALITPURBLOCK.shp
# Executing 1677st file
# Table 'LALITPURCANAL_6861525c' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lalitpur\LALITPURCANAL.shp
# Executing 1678st file
# Table 'LALITPURDEMOGRAPHY_6d1f3fd5' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lalitpur\LALITPURDEMOGRAPHY.shp
# Executing 1679st file
# Table 'LALITPURDISTRICT_e0b3d3c6' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lalitpur\LALITPURDISTRICT.shp
# Executing 1680st file
# Table 'LALITPURDRAINL_d2b372f2' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lalitpur\LALITPURDRAINL.shp
# Executing 1681st file
# Table 'LALITPURDRAINP_6047b2e2' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lalitpur\LALITPURDRAINP.shp
# Executing 1682st file
# Table 'LALITPURFOREST_91ccf00a' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lalitpur\LALITPURFOREST.shp
# Executing 1683st file
# Table 'LALITPURGEOM_87e785fd' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lalitpur\LALITPURGEOM.shp
# Executing 1684st file
# Table 'LALITPURGWATER_5a148369' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lalitpur\LALITPURGWATER.shp
# Executing 1685st file
# Table 'LALITPURLITHO_3415e1d1' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lalitpur\LALITPURLITHO.shp
# Executing 1686st file
# Table 'LALITPURLULC_1ce79a7f' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lalitpur\LALITPURLULC.shp
# Executing 1687st file
# Table 'LALITPURRAIL_58aef254' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lalitpur\LALITPURRAIL.shp
# Executing 1688st file
# Table 'LALITPURROAD_36c9fb9c' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lalitpur\LALITPURROAD.shp
# Executing 1689st file
# Table 'LALITPURSETA_249ce510' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lalitpur\LALITPURSETA.shp
# Executing 1690st file
# Table 'LALITPURSETTLEP_a41ea422' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lalitpur\LALITPURSETTLEP.shp
# Executing 1691st file
# Table 'LALITPURSOIL_8929a3be' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lalitpur\LALITPURSOIL.shp
# Executing 1692st file
# Table 'LALITPURSTRU_125c6020' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lalitpur\LALITPURSTRU.shp
# Executing 1693st file
# Table 'LALITPURTALUK_dc3faaa6' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lalitpur\LALITPURTALUK.shp
# Executing 1694st file
# Table 'LALITPURVILL_0dbaf270' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lalitpur\LALITPURVILL.shp
# Executing 1695st file
# Table 'LALITPURWELL_1d25a31f' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lalitpur\LALITPURWELL.shp
# Executing 1696st file
# Table 'LALITPURWSHED_090b1866' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lalitpur\LALITPURWSHED.shp
# Executing 1697st file
# Table 'LUCKNOWAMENITY_e86b4027' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lucknow\LUCKNOWAMENITY.shp
# Executing 1698st file
# Table 'LUCKNOWBLOCK_b0113a1d' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lucknow\LUCKNOWBLOCK.shp
# Executing 1699st file
# Table 'LUCKNOWCANAL_0d0aac49' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lucknow\LUCKNOWCANAL.shp
# Executing 1700st file
# Table 'LUCKNOWDEMOGRAPHY_7cbb22ea' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lucknow\LUCKNOWDEMOGRAPHY.shp
# Executing 1701st file
# Table 'LUCKNOWDISTRICT_32b29233' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lucknow\LUCKNOWDISTRICT.shp
# Executing 1702st file
# Table 'LUCKNOWDRAINL_cbe3ac70' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lucknow\LUCKNOWDRAINL.shp
# Executing 1703st file
# Table 'LUCKNOWDRAINP_ec88fc39' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lucknow\LUCKNOWDRAINP.shp
# Executing 1704st file
# Table 'LUCKNOWFOREST_1fd411d5' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lucknow\LUCKNOWFOREST.shp
# Executing 1705st file
# Table 'LUCKNOWGEOM_b90dd686' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lucknow\LUCKNOWGEOM.shp
# Executing 1706st file
# Table 'LUCKNOWGWATER_448feaa6' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lucknow\LUCKNOWGWATER.shp
# Executing 1707st file
# Table 'LUCKNOWLITHO_e2d3c03f' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lucknow\LUCKNOWLITHO.shp
# Executing 1708st file
# Table 'LUCKNOWLULC_7a939304' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lucknow\LUCKNOWLULC.shp
# Executing 1709st file
# Table 'LUCKNOWRAIL_8cfcc390' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lucknow\LUCKNOWRAIL.shp
# Executing 1710st file
# Table 'LUCKNOWROAD_f508c91c' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lucknow\LUCKNOWROAD.shp
# Executing 1711st file
# Table 'LUCKNOWSETA_a8dabf67' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lucknow\LUCKNOWSETA.shp
# Executing 1712st file
# Table 'LUCKNOWSETTLEP_527833ab' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lucknow\LUCKNOWSETTLEP.shp
# Executing 1713st file
# Table 'LUCKNOWSOIL_a1dff781' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lucknow\LUCKNOWSOIL.shp
# Executing 1714st file
# Table 'LUCKNOWSTRU_ea638141' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lucknow\LUCKNOWSTRU.shp
# Executing 1715st file
# Table 'LUCKNOWTALUK_7d49a8b0' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lucknow\LUCKNOWTALUK.shp
# Executing 1716st file
# Table 'LUCKNOWVILL_9c0b9281' already exists. \\192.168.1.151\ncfc_data3\CHAMAN\India_Statewise_Shapes\uttar_pradesh\NRIS DATA\Lucknow\LUCKNOWVILL.shp
# Executing 1717st file

# %%
pip install multiprocesspandas
from multiprocesspandas import applyparallel
def func(x):
        return x.mean()

    df.apply_parallel(func, num_processes=30, axis=1, n_chunks=None)
# Out:
#   File <tokenize>:5
#     df.apply_parallel(func, num_processes=30, axis=1, n_chunks=None)
#     ^
# IndentationError: unindent does not match any outer indentation level
