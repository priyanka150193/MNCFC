# %%
from sqlalchemy import create_engine
import geopandas as gp
import multiprocessing
import zipfile as zp
import pandas as pd
import numpy as np
import shutil
import os
from IPython.display import clear_output, display
import time
import concurrent.futures as cf
import psycopg2
from datetime import datetime
import geoalchemy2
#engine.dispose()

df = pd.read_csv(r'E:\combined.csv')
shp_df = df[df.Ext == 'shp']
shp_df.head()


# Function to read shape files into a temp directory
def shp_zip_read(full_path):
    os.makedirs(r"E:\New folder", exist_ok=True)
    zip_file_path = full_path.split('.zip\\')[0] + '.zip'
    shp_file_path = full_path.split('.zip\\')[1]
    print(shp_file_path)
    archive = zp.ZipFile(zip_file_path)
    if '/' not in shp_file_path:
        for file in archive.namelist():
            if '/' not in file:
                archive.extract(file, r"E:\New folder")
    else:
        shp_folder_path = '/'.join(shp_file_path.split('/')[:-1])+'/'
        for file in archive.namelist():
            if file.startswith(shp_folder_path):
                archive.extract(file, r"E:\New folder")
    gdf = gp.read_file("E:\\New folder\\{}".format(shp_folder_path))
    shutil.rmtree(r'E:\New folder', ignore_errors=True)
    return gdf


# Function to dump shape files into postgres db 
def shape_file_dump(file_name, file_path, engine):
    
    #connection = engine.connect()
    
    # Reading the shape file
    if '.zip' in file_path:
        gdf = shp_zip_read(file_path)
    else:
        gdf = gp.read_file(file_path)

    #Import shapefile to databse
    #print(file_name)
    gdf.to_postgis(name=file_name, con=engine, schema="postgis")
    
    #connection.close()
    

# Deriving a unique file name to create table in the database 
import hashlib
class FilePathShortener:
    def __init__(self):
        self.paths = {}
    
    def shorten_file_path(self, file_path):
        if file_path in self.paths:
            return self.paths[file_path]
        
        file_hash = hashlib.md5(file_path.encode()).hexdigest()
        shortened_path = file_hash[:8]
        
        self.paths[file_path] = shortened_path
        return shortened_path
    
    def decode_shortened_path(self, shortened_path):
        for path, short_path in self.paths.items():
            if short_path == shortened_path:
                return path
        
        return None

shortener = FilePathShortener()

 

"""file_path = '\\\\192.168.1.151\\ncfc_data3\\Neetu Mam (IP 26 Data Backup 17 April 23)\\Backup_Del\\Transfer-data\\Sent-Analysis\\shp\\0.India_state_shp\\india state_lcc.shp'
shortened_path = shortener.shorten_file_path(file_path)
print(shortened_path)"""

shortened_path = shp_df.File_path.apply(shortener.shorten_file_path) 
new_file_name = shp_df.File_Name+'_'+shortened_path
shp_df['unique_file_name']=new_file_name
        
    


# Getting the current date and time
#dt = datetime.now()
# getting the timestamp
#ts = datetime.timestamp(dt)
#print("Date and time is:", dt)
#current_time = dt.strftime("%d-%m-%Y %H:%M:%S")

    
if __name__ == '__main__':
    # Number of processes to run in parallel
    num_processes = multiprocessing.cpu_count()
        
    #DB details
    host = 'localhost'
    port = '5432'
    database = 'postgis_33'
    user = 'postgres'
    password = 'wadhwanikdss'

    conn = f"postgresql://{user}:{password}@{host}:{port}/{database}"
    engine = create_engine(conn)
            
#     # Create a list to store the process instances
#     processes = []

#     for _ in range(num_processes):
#         p = multiprocessing.Process(target=shape_file_dump, args=(list(shp_df.File_Name), list(shp_df.File_path), engine))
#         p.start()
#         processes.append(p)

#     # Wait for all processes to finish
#     for p in processes:
#         p.join()
    
    j = 1
    
    
      
for i in range(shp_df.shape[0]):
    df = pd.DataFrame(columns=['iteration','unique_file_name', 'file_path', 'error', 'error_type']) 
        # Getting the current date and time
    dt = datetime.now()
            # getting the timestamp
    ts = datetime.timestamp(dt)
    current_time = dt.strftime("%d-%m-%Y %H:%M:%S")
           #Appending  unique_file_name column with current timestamp
        
    pg_file_name = shp_df.unique_file_name.iloc[i] +'_' +current_time
            
    shp_df.unique_file_name.iloc[i] = pg_file_name
    
    if '.zip' not in shp_df.File_path.iloc[i]:  
        continue
    
    file_present = False
    #print('waiting for shared drive access ')
    while file_present == False:
            if os.path.exists(r'\\192.168.1.151\ncfc_data3\CHAMAN\mango\East Champaran\analysis\merge_mango_echamparan.shp'):
                print(f'Executing {i}st file')
            #Initialising empty dataframe to store exceptions
            
           
                try:
                     shape_file_dump(shp_df.unique_file_name.iloc[i], shp_df.File_path.iloc[i], engine)
            #print(shp_df.unique_file_name.iloc[i])
                except Exception as e:
                            error=e
                            print(error, shp_df.File_path.iloc[i])
                            if 'Identifier' not in str(error):
                                df.loc[len(df.index)] = [i,pg_file_name, shp_df.File_path.iloc[i], error, type(error)]
                #df.file_name.iloc[i] = shp_df.unique_file_name.iloc[i]
                                df.to_csv(f"C:/Users/user/Documents/Shape_file_DB_Upload_Error_tracker.csv" , mode='a', index=False, header=False)
               
                    #if type(error) == fiona.errors.DriverError:
                file_present = True
                break 
            
            else :
                print('waiting for shared drive access ') 
                time.sleep(40)
            

print("Data dumped successfully into the PostGIS database.")
    
engine.dispose()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df['unique_file_name']=new_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 25st file
# input_files/freeburg_xs_line.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 26st file
# input_files/freeburg_xs_poly.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 27st file
# input_files/freeburg_xs_wells.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 28st file
# input_files/xsec_A_poly.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 29st file
# output_files/3d_polys.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 30st file
# output_files/3d_test.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 31st file
# output_files/xsec_A_BT.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 32st file
# output_files/xsec_A_depths.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 33st file
# output_files/xsec_A_geophys.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 34st file
# output_files/xsec_A_geopts.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 35st file
# output_files/xsec_A_GridLine.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 36st file
# output_files/xsec_A_profile.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 37st file
# output_files/xsec_A_wellln.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 38st file
# output_files/xsec_A_wellpt.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 53st file
# shape/NCFCCrop2017062392731.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 55st file
# shape/NCFCCrop2017112161157.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 61st file
# shape/NCFCCrop20180125123034.shp
# Identifier 'idx_NCFCCrop20180125123034_ee451ca7_21-06-2023 11:19:28_geometry' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\Akhilesh\Wheat\F1\2017-18\Ground truth\NCFCCrop20180125123034_up.zip\shape/NCFCCrop20180125123034.shp
# Executing 63st file
# shape/Chaman20160718104510.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 94st file
# shape/NCFCCrop2017022184735.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 97st file
# shape/NCFCCrop2017022184735.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 120st file
# Cat1.shp
# local variable 'shp_folder_path' referenced before assignment \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\esri\ARC1\Florida\StormSurge.zip\Cat1.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 121st file
# Cat2.shp
# local variable 'shp_folder_path' referenced before assignment \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\esri\ARC1\Florida\StormSurge.zip\Cat2.shp
# Executing 122st file
# Cat3.shp
# local variable 'shp_folder_path' referenced before assignment \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\esri\ARC1\Florida\StormSurge.zip\Cat3.shp
# Executing 123st file
# Cat4_5.shp
# local variable 'shp_folder_path' referenced before assignment \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\esri\ARC1\Florida\StormSurge.zip\Cat4_5.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 125st file
# ParkingFacilities.shp
# local variable 'shp_folder_path' referenced before assignment \\192.168.1.151\ncfc_data3\CHAMAN\ArcGIS_Training Manual\esri\ARC1\OnlineFiles\ParkingFacilities.zip\ParkingFacilities.shp
# Executing 133st file
# shape/NCFCCrop2016061383541.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# ...
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Identifier 'idx_BhuvanFASAL2022110392952_c4bd23ca_21-06-2023 11:23:42_geometry' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\Neetu Mam (IP 26 Data Backup 17 April 23)\5-5-2022_office_work\GT_Noncereals\new_download\13_08_2022.zip\shape/BhuvanFASAL2022110392952.shp
# Executing 2949st file
# shape/BhuvanFASAL2022110393727.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Identifier 'idx_BhuvanFASAL2022110393727_b3fea6f5_21-06-2023 11:23:43_geometry' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\Neetu Mam (IP 26 Data Backup 17 April 23)\5-5-2022_office_work\GT_Noncereals\new_download\20_08_2022.zip\shape/BhuvanFASAL2022110393727.shp
# Executing 2950st file
# shape/BhuvanFASAL20221103103015.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Identifier 'idx_BhuvanFASAL20221103103015_ad1d7633_21-06-2023 11:23:46_geometry' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\Neetu Mam (IP 26 Data Backup 17 April 23)\5-5-2022_office_work\GT_Noncereals\new_download\24_08_2022.zip\shape/BhuvanFASAL20221103103015.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 2951st file
# shape/BhuvanFASAL20221103103818.shp
# Identifier 'idx_BhuvanFASAL20221103103818_e627dcb9_21-06-2023 11:23:49_geometry' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\Neetu Mam (IP 26 Data Backup 17 April 23)\5-5-2022_office_work\GT_Noncereals\new_download\27_08_2022.zip\shape/BhuvanFASAL20221103103818.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 2952st file
# shape/BhuvanFASAL2022092155137.shp
# Identifier 'idx_BhuvanFASAL2022092155137_af6c8663_21-06-2023 11:23:55_geometry' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\Neetu Mam (IP 26 Data Backup 17 April 23)\5-5-2022_office_work\GT_Noncereals\RJ\Rajasthan 1-24aug.zip\shape/BhuvanFASAL2022092155137.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 2953st file
# shape/BhuvanFASAL2022092151719.shp
# Identifier 'idx_BhuvanFASAL2022092151719_26bb2924_21-06-2023 11:23:59_geometry' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\Neetu Mam (IP 26 Data Backup 17 April 23)\5-5-2022_office_work\GT_Noncereals\RJ\Rajasthan 28aug-21sepRJ.zip\shape/BhuvanFASAL2022092151719.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 2958st file
# shape/NCFCCrop20170102101641.shp
# Identifier 'idx_NCFCCrop20170102101641_51a14a04_21-06-2023 11:24:03_geometry' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\CHAMAN\nhrdf_khariff_onion2016-17\GT File\NCFCCrop20170102101641.zip\shape/NCFCCrop20170102101641.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 2959st file
# shape/NCFCCrop20170102104445.shp
# Identifier 'idx_NCFCCrop20170102104445_d6afd6ba_21-06-2023 11:24:05_geometry' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\CHAMAN\nhrdf_khariff_onion2016-17\GT File\NCFCCrop20170102104445.zip\shape/NCFCCrop20170102104445.shp
# Executing 2960st file
# shape/NCFCCrop20170102104820.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Identifier 'idx_NCFCCrop20170102104820_53d1dc23_21-06-2023 11:24:07_geometry' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\CHAMAN\nhrdf_khariff_onion2016-17\GT File\NCFCCrop20170102104820.zip\shape/NCFCCrop20170102104820.shp
# Executing 2961st file
# shape/NCFCCrop20170102104830.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Identifier 'idx_NCFCCrop20170102104830_cb55f600_21-06-2023 11:24:07_geometry' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\CHAMAN\nhrdf_khariff_onion2016-17\GT File\NCFCCrop20170102104830.zip\shape/NCFCCrop20170102104830.shp
# Executing 2962st file
# shape/NCFCCrop20170102105037.shp
# C:\Users\user\AppData\Local\Temp\ipykernel_16824\3483513846.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Identifier 'idx_NCFCCrop20170102105037_f0df4351_21-06-2023 11:24:08_geometry' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\CHAMAN\nhrdf_khariff_onion2016-17\GT File\NCFCCrop20170102105037.zip\shape/NCFCCrop20170102105037.shp
# Executing 2963st file
# shape/NCFCCrop20170102105404.shp
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# waiting for shared drive access
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 178
#     176             else :
#     177                 print('waiting for shared drive access ')
# --> 178                 time.sleep(40)
#     181 print("Data dumped successfully into the PostGIS database.")
#     183 engine.dispose()
#
# KeyboardInterrupt:

# %%
if os.path.exists(r'\\192.168.1.151\ncfc_data3\CHAMAN\mango\East Champaran\analysis\merge_mango_echamparan.shp'):
    print('read')
# Out:
# read

# %%
print(i)
# Out:
# 3818

# %%
for i in range 10 :
    print

# %%
shp_df.shape[0]
# Out:
# 98875
