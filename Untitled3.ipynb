# %%
from sqlalchemy import create_engine
import geopandas as gp
import multiprocessing
import zipfile as zp
import pandas as pd
import numpy as np
import shutil
import os
from IPython.display import clear_output, display
import time
import concurrent.futures as cf
import psycopg2
from datetime import datetime
import geoalchemy2
#engine.dispose()

df = pd.read_csv(r'E:\combined.csv')
shp_df = df[df.Ext == 'shp']
shp_df.head()


# Function to read shape files into a temp directory
def shp_zip_read(full_path):
    os.makedirs(r"E:\New folder", exist_ok=True)
    zip_file_path = full_path.split('.zip\\')[0]
    shp_file_path = full_path.split('.zip\\')[1]
    archive = zp.ZipFile(zip_file_path)
    if '/' not in shp_file_path:
        for file in archive.namelist():
            if '/' not in file:
                archive.extract(file, r"E:\New folder")
    else:
        shpfile_folder_path = '/'.join(file_zip_path.split('/')[:-1])+'/'
        for file in archive.namelist():
            if file.startswith(shpfile_folder_path):
                archive.extract(file, r"E:\New folder")
    gdf = gp.read_file(r"E:\New folder\{}".format(file_zip_path))
    shutil.rmtree(r'E:\New folder', ignore_errors=True)
    return gdf


# Function to dump shape files into postgres db 
def shape_file_dump(file_name, file_path, engine):
    
    #connection = engine.connect()
    
    # Reading the shape file
    if '.zip' in file_path:
        gdf = shp_zip_read(file_path)
    else:
        gdf = gp.read_file(file_path)

    #Import shapefile to databse
    #print(file_name)
    gdf.to_postgis(name=file_name, con=engine, schema="postgis")
    
    #connection.close()
    

# Deriving a unique file name to create table in the database 
import hashlib
class FilePathShortener:
    def __init__(self):
        self.paths = {}
    
    def shorten_file_path(self, file_path):
        if file_path in self.paths:
            return self.paths[file_path]
        
        file_hash = hashlib.md5(file_path.encode()).hexdigest()
        shortened_path = file_hash[:8]
        
        self.paths[file_path] = shortened_path
        return shortened_path
    
    def decode_shortened_path(self, shortened_path):
        for path, short_path in self.paths.items():
            if short_path == shortened_path:
                return path
        
        return None

shortener = FilePathShortener()

 

"""file_path = '\\\\192.168.1.151\\ncfc_data3\\Neetu Mam (IP 26 Data Backup 17 April 23)\\Backup_Del\\Transfer-data\\Sent-Analysis\\shp\\0.India_state_shp\\india state_lcc.shp'
shortened_path = shortener.shorten_file_path(file_path)
print(shortened_path)"""

shortened_path = shp_df.File_path.apply(shortener.shorten_file_path) 
new_file_name = shp_df.File_Name+'_'+shortened_path
shp_df['unique_file_name']=new_file_name
        
    


# Getting the current date and time
#dt = datetime.now()
# getting the timestamp
#ts = datetime.timestamp(dt)
#print("Date and time is:", dt)
#current_time = dt.strftime("%d-%m-%Y %H:%M:%S")

    
if __name__ == '__main__':
    # Number of processes to run in parallel
    num_processes = multiprocessing.cpu_count()
        
    #DB details
    host = 'localhost'
    port = '5432'
    database = 'postgis_33'
    user = 'postgres'
    password = 'wadhwanikdss'

    conn = f"postgresql://{user}:{password}@{host}:{port}/{database}"
    engine = create_engine(conn)
            
#     # Create a list to store the process instances
#     processes = []

#     for _ in range(num_processes):
#         p = multiprocessing.Process(target=shape_file_dump, args=(list(shp_df.File_Name), list(shp_df.File_path), engine))
#         p.start()
#         processes.append(p)

#     # Wait for all processes to finish
#     for p in processes:
#         p.join()
    
    j = 1
    
    
      
for i in range(shp_df.shape[0]):
    df = pd.DataFrame(columns=['iteration','unique_file_name', 'file_path', 'error', 'error_type']) 
        # Getting the current date and time
    dt = datetime.now()
            # getting the timestamp
    ts = datetime.timestamp(dt)
    current_time = dt.strftime("%d-%m-%Y %H:%M:%S")
           #Appending  unique_file_name column with current timestamp
        
    pg_file_name = shp_df.unique_file_name.iloc[i] +'_' +current_time
            
    shp_df.unique_file_name.iloc[i] = pg_file_name
    
    if '.zip' in shp_df.File_path.iloc[i]:  
        continue
    
    file_present = False
    #print('waiting for shared drive access ')
    while file_present == False:
            if os.path.exists(shp_df.File_path.iloc[i]):
                print(f'Executing {i}st file')
            #Initialising empty dataframe to store exceptions
            
           
                try:
                     shape_file_dump(shp_df.unique_file_name.iloc[i], shp_df.File_path.iloc[i], engine)
            #print(shp_df.unique_file_name.iloc[i])
                except Exception as e:
                            error=e
                            print(error, shp_df.File_path.iloc[i])
                            if 'Identifier' not in str(error):
                                df.loc[len(df.index)] = [i,pg_file_name, shp_df.File_path.iloc[i], error, type(error)]
                #df.file_name.iloc[i] = shp_df.unique_file_name.iloc[i]
                                df.to_csv(f"C:/Users/user/Documents/Shape_file_DB_Upload_Error_tracker.csv" , mode='a', index=False, header=False)
               
                    #if type(error) == fiona.errors.DriverError:
                file_present = True
                break 
            
            else :
                print('waiting for shared drive access ') 
                time.sleep(40)
            

print("Data dumped successfully into the PostGIS database.")
    
engine.dispose()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df['unique_file_name']=new_file_name
# Executing 0st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 1st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 2st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 3st file
# Executing 4st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 5st file
# Executing 6st file
# Executing 7st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 8st file
# Executing 9st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 10st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 11st file
# Executing 12st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 13st file
# Executing 14st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 15st file
# Identifier 'idx_Obstacle Route_polyline_6572b6e6_20-06-2023 19:15:17_geometry' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\Akhilesh\akhileshPP\PP_work\lulc_manoj\SHP\Obstacle Route_polyline.shp
# Executing 16st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 17st file
# Executing 18st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 19st file
# Executing 20st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 21st file
# Executing 22st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 23st file
# Executing 24st file
# Executing 39st file
# Executing 40st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 41st file
# Executing 42st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 43st file
# Executing 44st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 45st file
# Executing 46st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 47st file
# C:\Users\user\miniconda3\envs\kdss_base\lib\site-packages\geopandas\io\sql.py:415: UserWarning: Could not parse CRS from the GeoDataFrame. Inserting data without defined CRS.
#   srid = _get_srid_from_crs(gdf)
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 48st file
# Executing 49st file
# C:\Users\user\miniconda3\envs\kdss_base\lib\site-packages\geopandas\io\sql.py:415: UserWarning: Could not parse CRS from the GeoDataFrame. Inserting data without defined CRS.
#   srid = _get_srid_from_crs(gdf)
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 50st file
# Executing 51st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 52st file
# Executing 54st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 56st file
# Executing 57st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 58st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 59st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 60st file
# Identifier 'idx_UP_withoutcloudDistrict_e18c4ff1_20-06-2023 19:15:40_geometry' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\Akhilesh\Wheat\F1\2017-18\AWiFS_ndvi_product\Cloud Free\UP_withoutcloudDistrict.shp
# Executing 62st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Identifier 'idx_NCFCCrop20180125123034_9d019779_20-06-2023 19:15:41_geometry' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\Akhilesh\Wheat\F1\2017-18\Ground truth\NCFCCrop20180125123034_up\shape\NCFCCrop20180125123034.shp
# Executing 64st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 65st file
# Executing 66st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 67st file
# Executing 68st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Identifier 'idx_NCFCCrop20160218115847_502e3555_20-06-2023 19:15:42_geometry' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\CHAMAN\aditi\gujarat GT\NCFCCrop20160218115847.shp
# Executing 69st file
# Executing 70st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 71st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 72st file
# Executing 73st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 74st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 75st file
# Executing 76st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 77st file
# Executing 78st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 79st file
# Executing 80st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 81st file
# Executing 82st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 83st file
# Executing 84st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 85st file
# Executing 86st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 87st file
# Executing 88st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 89st file
# Executing 90st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 91st file
# Executing 92st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 93st file
# Executing 95st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 96st file
# Executing 98st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 99st file
# Identifier 'idx_NCFCCrop20170102104820_8816885e_20-06-2023 19:15:56_geometry' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\CHAMAN\andhrapradesh telenagana chilli 2016_17\Bihar chilli_tomato\NCFCCrop20170102104820\shape\NCFCCrop20170102104820.shp
# Executing 100st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\miniconda3\envs\kdss_base\lib\site-packages\geopandas\io\sql.py:415: UserWarning: Could not parse CRS from the GeoDataFrame. Inserting data without defined CRS.
#   srid = _get_srid_from_crs(gdf)
# Executing 101st file
# Executing 102st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 103st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\miniconda3\envs\kdss_base\lib\site-packages\geopandas\io\sql.py:415: UserWarning: Could not parse CRS from the GeoDataFrame. Inserting data without defined CRS.
#   srid = _get_srid_from_crs(gdf)
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 104st file
# Executing 105st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 106st file
# Executing 107st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 108st file
# Executing 109st file
# C:\Users\user\miniconda3\envs\kdss_base\lib\site-packages\geopandas\io\sql.py:415: UserWarning: Could not parse CRS from the GeoDataFrame. Inserting data without defined CRS.
#   srid = _get_srid_from_crs(gdf)
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\miniconda3\envs\kdss_base\lib\site-packages\geopandas\io\sql.py:415: UserWarning: Could not parse CRS from the GeoDataFrame. Inserting data without defined CRS.
#   srid = _get_srid_from_crs(gdf)
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\miniconda3\envs\kdss_base\lib\site-packages\geopandas\io\sql.py:415: UserWarning: Could not parse CRS from the GeoDataFrame. Inserting data without defined CRS.
#   srid = _get_srid_from_crs(gdf)
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\miniconda3\envs\kdss_base\lib\site-packages\geopandas\io\sql.py:415: UserWarning: Could not parse CRS from the GeoDataFrame. Inserting data without defined CRS.
#   srid = _get_srid_from_crs(gdf)
# Executing 110st file
# Executing 111st file
# Executing 112st file
# Executing 113st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\miniconda3\envs\kdss_base\lib\site-packages\geopandas\io\sql.py:415: UserWarning: Could not parse CRS from the GeoDataFrame. Inserting data without defined CRS.
#   srid = _get_srid_from_crs(gdf)
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\miniconda3\envs\kdss_base\lib\site-packages\geopandas\io\sql.py:415: UserWarning: Could not parse CRS from the GeoDataFrame. Inserting data without defined CRS.
#   srid = _get_srid_from_crs(gdf)
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 114st file
# Executing 115st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 116st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 117st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 118st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# ...
# Executing 2361st file
# Executing 2362st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 2363st file
# Identifier 'idx_104_53a_11april15_initialseg_2c9485c7_20-06-2023 22:21:58_geometry' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\CHAMAN\mango\East Champaran\analysis\104_53a_11april15_initialseg.shp
# Executing 2364st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Identifier 'idx_104_53a_11april15_initialseg1_04d794b9_20-06-2023 22:38:13_geometry' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\CHAMAN\mango\East Champaran\analysis\104_53a_11april15_initialseg1.shp
# Executing 2365st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 2366st file
# Identifier 'idx_104_53a_18Nov13_initialseg_0e78e927_20-06-2023 23:08:37_geometry' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\CHAMAN\mango\East Champaran\analysis\104_53a_18Nov13_initialseg.shp
# Executing 2367st file
# Executing 2368st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Identifier 'idx_104_53b_1april15_initailseg_cab7aaf8_20-06-2023 23:13:32_geometry' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\CHAMAN\mango\East Champaran\analysis\104_53b_1april15_initailseg.shp
# Executing 2369st file
# Executing 2370st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Identifier 'idx_104_53b_30april14_initialseg_d0b58565_20-06-2023 23:14:18_geometry' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\CHAMAN\mango\East Champaran\analysis\104_53b_30april14_initialseg.shp
# Executing 2371st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 2372st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 2373st file
# Identifier 'idx_merge_mango_echamparan_8ff5acd4_20-06-2023 23:23:50_geometry' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\CHAMAN\mango\East Champaran\analysis\merge_mango_echamparan.shp
# Executing 2374st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 2375st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 2376st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 2377st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 2378st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 2379st file
# Identifier 'mango_100_52ac_15_apri_mayDiss_uninon_5edb4726_21-06-2023 02:13:14' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\CHAMAN\mango\Sitapur\final data set\mango_100_52ac_15_apri_mayDiss_uninon.shp
# Executing 2478st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Identifier 'mango_100_52ac_15_apri_mayDiss_unin_Diss2_145567f1_21-06-2023 02:14:21' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\CHAMAN\mango\Sitapur\final data set\mango_100_52ac_15_apri_mayDiss_unin_Diss2.shp
# Executing 2479st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Identifier 'idx_mango_100_52ac_4_may_2015_io_p1_D1_856c6e4e_21-06-2023 02:16:09_geometry' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\CHAMAN\mango\Sitapur\final data set\mango_100_52ac_4_may_2015_io_p1_D1.shp
# Executing 2482st file
# Executing 6175st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 6176st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 8408st file
# Identifier 'idx_BhuvanFASAL2022041163405_049dceca_21-06-2023 09:18:49_geometry' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\Neetu Mam (IP 26 Data Backup 17 April 23)\Dr. Kanthesh\Desktop 5-5-2022\PMFBY\GT_BHUVAN\TN\shape\BhuvanFASAL2022041163405.shp
# Executing 8409st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Identifier 'idx_BhuvanFASAL20220408122427_05711b5f_21-06-2023 09:18:51_geometry' exceeds maximum length of 63 characters \\192.168.1.151\ncfc_data3\Neetu Mam (IP 26 Data Backup 17 April 23)\Dr. Kanthesh\Desktop 5-5-2022\PMFBY\GT_BHUVAN\Uttar_Pradesh\shape\BhuvanFASAL20220408122427.shp
# Executing 8410st file
# Executing 8411st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 8412st file
# Executing 8413st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 8414st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 8415st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 8416st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 8433st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 8434st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 8435st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 8436st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 8437st file
# C:\Users\user\AppData\Local\Temp\ipykernel_1444\3444764998.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shp_df.unique_file_name.iloc[i] = pg_file_name
# Executing 8438st file
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 177
#     175             else :
#     176                 print('waiting for shared drive access ')
# --> 177                 time.sleep(40)
#     180 print("Data dumped successfully into the PostGIS database.")
#     182 engine.dispose()
#
# KeyboardInterrupt:

# %%
import pandas as pd
df = pd.read_csv(r'E:\combined.csv')
shp_df = df[df.Ext == 'shp']
shp_df.head()

for i in range(10):
    while os.path.exists(shp_df.File_path.iloc[i]):
        print(i)

# %%
print(i)
# Out:
# 8951

# %%
import os.path
import time
import pandas as pd
df = pd.read_csv(r'E:\combined.csv')
shp_df = df[df.Ext == 'shp']
shp_df.head()

for i in range(shp_df.shape[0]):
    file_present = False
    #print('waiting for shared drive access ')
    while file_present == False:
        if os.path.exists(shp_df.File_path.iloc[i]):
            print('reading ',i)
            file_present = True
            break
        else :
            print('waiting for shared drive access ') 
            time.sleep(20)

# %%
shp_df.File_path.iloc[25]

# %%
file_path1 = '\\\\192.168.1.151\\ncfc_data3\\Akhilesh\\akhileshPP\\PP_work\\RD\\xacto_ArcGIS101_062014.zip\\input_files/freeburg_xs_line.shp'
def shp_zip_read(full_path1):
    os.makedirs(r"E:\New folder", exist_ok=True)
    zip_file_path = full_path.split('.zip\\')[0]
    shp_file_path = full_path.split('.zip\\')[1]
    archive = zp.ZipFile(zip_file_path)
    if '/' not in shp_file_path:
        for file in archive.namelist():
            if '/' not in file:
                archive.extract(file, r"E:\New folder")
    else:
        shpfile_folder_path = '/'.join(file_zip_path.split('/')[:-1])+'/'
        for file in archive.namelist():
            if file.startswith(shpfile_folder_path):
                archive.extract(file, r"E:\New folder")
    gdf = gp.read_file(r"E:\New folder\{}".format(file_zip_path))
    shutil.rmtree(r'E:\New folder', ignore_errors=True)
    return gdf


if os.path.exists('\\\\192.168.1.151\\ncfc_data3\\Akhilesh\\akhileshPP\\PP_work\\RD\\xacto_ArcGIS101_062014.zip\\input_files/freeburg_xs_line.shp'):
            print('reading ' )
            gdf = shp_zip_read(file_path)
            display(gdf)
else: print('no ')

# %%
file_path_=pd.DataFrame(columns=['iteration']) 
file_path_['iteration']= '\\\\192.168.1.151\\ncfc_data3\\Akhilesh\\akhileshPP\\PP_work\\RD\\xacto_ArcGIS101_062014.zip\\input_files/freeburg_xs_line.shp'
os.makedirs(r"E:\New folder", exist_ok=True)
zip_file_path = full_path_.iteration.split('.zip\\')[0]
shp_file_path = full_path_.iteration.split('.zip\\')[1]
archive = zp.ZipFile(zip_file_path)
if '/' not in shp_file_path:
        for file in archive.namelist():
            if '/' not in file:
                archive.extract(file, r"E:\New folder")
else:
        shpfile_folder_path = '/'.join(file_zip_path.split('/')[:-1])+'/'
        for file in archive.namelist():
            if file.startswith(shpfile_folder_path):
                archive.extract(file, r"E:\New folder")
                
gdf = gp.read_file(r"E:\New folder\{}".format(file_zip_path))

# %%
shutil.rmtree(r'E:\New folder', ignore_errors=True)

# %%
file_path_= pd.Dataframe("\\\\192.168.1.151\\ncfc_data3\\Akhilesh\\akhileshPP\\PP_work\\RD\\xacto_ArcGIS101_062014.zip\\input_files/freeburg_xs_line.shp")
file_path_
